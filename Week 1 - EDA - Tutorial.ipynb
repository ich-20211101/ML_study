# %% [markdown]
# <a href="https://colab.research.google.com/github/ich-20211101/appliedMultivariateStatisticalAnalysis/blob/main/Week%201%20-%20EDA%20-%20Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ich-20211101/appliedMultivariateStatisticalAnalysis/refs/heads/main/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.shape #(행, 열)
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df[df.duplicated()] # Check for Duplicates
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# Plot
plt.title('Count of Number of Each Outcome')
sns.countplot(x='Outcome',data=df)
# Out:
# <Axes: title={'center': 'Count of Number of Each Outcome'}, xlabel='Outcome', ylabel='count'>

# %%
# Print Pearson R correlation matrix
# +1: 완벽한 양의 상관관계 (같이 증가) / -1: 완벽한 음의 상관관계 (한쪽 증가, 한쪽 감소)
# 0: 상관 없음 / +0.8, -0.8: 강한 상관관계 (방향만 다름)
corr_matrix = df.corr(method='pearson')
corr_matrix
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# Visualize correlation matrix, which will show the correlations between the predictor variables with each other, and with the target ('Outcome')
corr_matrix.style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_a3627_row0_col0, #T_a3627_row1_col1, #T_a3627_row2_col2, #T_a3627_row3_col3, #T_a3627_row4_col4, #T_a3627_row5_col5, #T_a3627_row6_col6, #T_a3627_row7_col7, #T_a3627_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a3627_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_a3627_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_a3627_row0_col3, #T_a3627_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_a3627_row0_col4, #T_a3627_row0_col5, #T_a3627_row0_col6, #T_a3627_row2_col8, #T_a3627_row3_col0, #T_a3627_row3_col1, #T_a3627_row3_col7, #T_a3627_row6_col2, #T_a3627_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a3627_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_a3627_row0_col8, #T_a3627_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_a3627_row1_col0 {
#   background-color: #799cf8;
# ...

# %%
sns.boxplot(x = 'Outcome', y = 'BMI', data = df)
# Out:
# <Axes: xlabel='Outcome', ylabel='BMI'>

# %%
df = df[df['BMI'] != 0]
df = df[df['BloodPressure'] != 0]

# %%
sns.scatterplot(x = 'BloodPressure', y = 'BMI', data = df)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='BMI'>

# %%
sns.regplot(x = 'BloodPressure', y = 'BMI', data = df)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='BMI'>

# %%
df.hist(bins=20,figsize=(10, 10))
plt.show()

# %%
sns.heatmap(df.corr(), annot = True)
plt.show()
